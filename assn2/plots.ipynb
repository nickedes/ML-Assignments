# %%
import matplotlib.pyplot as plt
x = [ 0.001393 , 0.004122,  0.006475  ,0.00882  , 0.011457]
y = [ 291585.14628698 , 299156.15373296 , 296035.01460425  ,314294.63907328,  314294.63907328]

plt.plot(x, y, marker='o')
plt.show()

# %%
l = [0,1,2,3,4,5]
mean = [34.287974902561736, 34.32524956975664, 36.495353255953106, 39.61912655830383, 36.78770661354065, 34.10909622056143] 
sd = [0.590236312944993, 0.6410637966219712, 2.0919148453619867, 2.111140024845801, 2.136815551472154, 0.8627498579129463]

# %% [markdown]
# plt.errorbar(l, mean, sd)

# %%
plt.errorbar(l, mean, sd, linestyle='None', marker='o')
plt.show()
